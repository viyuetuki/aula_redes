# %% [markdown]
# Problema das caixas não-binárias
# ================================

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Encontrar uma solução para o problema das caixas não-binárias usando um algoritmo genético. Considere 4 caixas. Considere que cada caixa pode ter um valor inteiro dentro do conjunto [0, 100].

# %% [markdown]
# ## Descrição do problema

# %% [markdown]
# O problema das caixas não-binárias é simples: nós temos um certo número de caixas e cada uma pode conter um número inteiro. O objetivo é encontrar uma combinação de caixas onde a soma dos valores contidos dentro delas é máximo.

# %% [markdown]
# ## Importações

# %%
# importando 'random' e algumas funções criadas, do arquivo 'funcoes.py', a serem usadas no algoritmo 
# e as renomeando de maneira "auto-explicativa"

from funcoes import populacao_cnb
from funcoes import funcao_objetivo_pop_cnb as funcao_objetivo_pop
from funcoes import selecao_roleta_max as funcao_selecao
from funcoes import cruzamento_ponto_simples as funcao_cruzamento
from funcoes import mutacao_cnb 
import random

# Obs: As que foram deixas sem a parte de renomeação é porque terão posição de funções locais neste código.
# Então, quando elas forem adaptadas para as especificidades deste problema, aproveita-se para renomeá-las.

# %% [markdown]
# ## Códigos e discussão

# %%
# constantes relacionadas à busca

TAMANHO_POP = 6
NUM_GERACOES = 1000
CHANCE_CRUZAMENTO = 0.5
CHANCE_MUTACAO = 0.04

# constantes relacionadas ao problema a ser resolvido (quando mudadas, altera-se o problema)

VALOR_MAX_CAIXA = 100
NUM_GENES = 4

# %%
# Funções locais
# -> funções pré-estabelecidas, de forma geral, em 'funcoes.py', sendo usadas neste código com constantes fixas
# específicas para o problema em questão 
# -> oportunidade aproveitada para renomeá-las

def cria_populacao_inicial(tamanho, numero_genes):
    return populacao_cnb(tamanho, numero_genes, VALOR_MAX_CAIXA)

def funcao_mutacao(individuo):
    return mutacao_cnb(individuo, VALOR_MAX_CAIXA)

# %%
# mesma lógica do experimento 3

# estabelece uma população inicial aleatória
populacao = cria_populacao_inicial(TAMANHO_POP, NUM_GENES)

print("População inicial:")
print(populacao)

# Metodologia adotada a seguir...
# Para cada geração desejada, até se atingir o número máximo especificado:
# - calcula e armazena o fitness da população;
# - faz a seleção dentre os indivíduos da antiga população, a partir dos dados
#   obtidos de fitness de cada um, reestabelecendo/formando uma nova população;
# - separa os indívuos pais (a partir do elemento de index 0, indo de 2 em 2) e
#   as mães (a partir do elemento de index 1, indo de 2 em 2);
# - para cada dupla de pai e mãe, considerando o conjunto das duas lista, caso 
#   seja sorteado um número (float) de 0 a 1 menor ou igual ao valor estabelecido 
#   de chance de cruzamento, ocorre o cruzamento dos respectivos pai e mãe, gerando 
#   2 filhos com a combinação dos dois. Com isso, também, os pais são substituídos 
#   pelos filhos na população;
# - e, para cada posição da nova população formada, se um número sorteado entre 0
#   e 1 for menor ou igual ao valor de chance de mutação, o indivíduo de respectivo 
#   index nos será apresentado, é aplicada a função de mutação nele e nos é apresentado 
#   o resultado
# Por fim, toda a população final é printada
for n in range(NUM_GERACOES):
    fitness = funcao_objetivo_pop(populacao)
    populacao = funcao_selecao(populacao, fitness)
    
    pais = populacao[0::2]
    maes = populacao[1::2]
    
    contador = 0
    
    for pai, mae in zip(pais, maes):
        if random.random() <= CHANCE_CRUZAMENTO:
            filho1, filho2 = funcao_cruzamento(pai, mae)
            populacao[contador] = filho1
            populacao[contador + 1] = filho2
        
        contador = contador + 2
        
    for n in range(len(populacao)):
        if random.random() <= CHANCE_MUTACAO:
            individuo = populacao[n]
            print()
            print("Indivíduo original: ", individuo)
            populacao[n] = funcao_mutacao(individuo)
            print("Indivíduo mutado: ", populacao[n])
            print()
    
print()
print("População final:")
print(populacao)
# Out:
# População inicial:
# [[49, 62, 32, 95], [34, 10, 32, 9], [49, 33, 63, 91], [9, 52, 12, 72], [67, 31, 19, 37], [45, 53, 2, 45]]
#
# Indivíduo original:  [9, 53, 2, 45]
# Indivíduo mutado:  [9, 53, 49, 45]
#
#
# Indivíduo original:  [49, 62, 63, 91]
# Indivíduo mutado:  [49, 42, 63, 91]
#
#
# Indivíduo original:  [49, 42, 63, 91]
# Indivíduo mutado:  [49, 42, 0, 91]
#
#
# Indivíduo original:  [49, 33, 32, 95]
# Indivíduo mutado:  [49, 32, 32, 95]
#
#
# Indivíduo original:  [49, 42, 0, 91]
# Indivíduo mutado:  [45, 42, 0, 91]
#
#
# Indivíduo original:  [45, 42, 0, 91]
# Indivíduo mutado:  [45, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [3, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 0, 91]
# Indivíduo mutado:  [45, 2, 0, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 24, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 58, 91]
#
#
# Indivíduo original:  [45, 42, 58, 91]
# Indivíduo mutado:  [45, 42, 58, 92]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 95, 75]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 12, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 6, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 100, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [99, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 37, 91]
#
#
# Indivíduo original:  [99, 42, 95, 91]
# Indivíduo mutado:  [35, 42, 95, 91]
#
#
# Indivíduo original:  [35, 42, 95, 91]
# Indivíduo mutado:  [35, 42, 46, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [41, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 38, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 95, 20]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 63, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [25, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [44, 42, 95, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 70, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 13, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 7, 91]
#
#
# Indivíduo original:  [45, 42, 95, 91]
# Indivíduo mutado:  [45, 42, 95, 23]
#
#
# Indivíduo original:  [45, 42, 70, 91]
# Indivíduo mutado:  [45, 42, 70, 5]
#
#
# Indivíduo original:  [45, 42, 70, 91]
# Indivíduo mutado:  [45, 42, 70, 11]
#
#
# Indivíduo original:  [45, 42, 95, 11]
# Indivíduo mutado:  [7, 42, 95, 11]
#
#
# Indivíduo original:  [45, 42, 70, 23]
# Indivíduo mutado:  [45, 42, 28, 23]
#
#
# Indivíduo original:  [45, 42, 70, 11]
# Indivíduo mutado:  [45, 42, 89, 11]
#
#
# Indivíduo original:  [45, 42, 70, 11]
# Indivíduo mutado:  [14, 42, 70, 11]
#
#
# Indivíduo original:  [45, 42, 70, 11]
# Indivíduo mutado:  [45, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 42, 18, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [3, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 66, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 42, 0, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 100, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [34, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 42, 70, 6]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [78, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [68, 42, 70, 72]
#
#
# Indivíduo original:  [78, 42, 70, 72]
# Indivíduo mutado:  [97, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [45, 42, 13, 72]
#
#
# Indivíduo original:  [97, 42, 70, 72]
# Indivíduo mutado:  [97, 42, 4, 72]
#
#
# Indivíduo original:  [97, 42, 13, 72]
# Indivíduo mutado:  [97, 92, 13, 72]
#
#
# Indivíduo original:  [97, 42, 13, 72]
# Indivíduo mutado:  [97, 42, 13, 8]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  [49, 42, 70, 72]
#
#
# Indivíduo original:  [45, 42, 70, 72]
# Indivíduo mutado:  
# Indivíduo mutado:  [97, 31, 44, 95]
#
#
# Indivíduo original:  [97, 80, 81, 95]
# Indivíduo mutado:  [97, 80, 17, 95]
#
#
# Indivíduo original:  [97, 80, 44, 95]
# Indivíduo mutado:  [97, 82, 44, 95]
#
#
# Indivíduo original:  [97, 31, 81, 95]
# Indivíduo mutado:  [97, 31, 61, 95]
#
#
# Indivíduo original:  [97, 31, 81, 95]
# Indivíduo mutado:  [59, 31, 81, 95]
#
#
# Indivíduo original:  [97, 31, 81, 95]
# Indivíduo mutado:  [98, 31, 81, 95]
#
#
# Indivíduo original:  [97, 31, 81, 95]
# Indivíduo mutado:  [97, 31, 41, 95]
#
#
# Indivíduo original:  [97, 31, 41, 95]
# Indivíduo mutado:  [97, 5, 41, 95]
#
#
# Indivíduo original:  [97, 31, 41, 95]
# Indivíduo mutado:  [99, 31, 41, 95]
#
#
# Indivíduo original:  [99, 31, 41, 95]
# Indivíduo mutado:  [74, 31, 41, 95]
#
#
# Indivíduo original:  [99, 31, 41, 95]
# Indivíduo mutado:  [99, 31, 83, 95]
#
#
# Indivíduo original:  [99, 31, 41, 95]
# Indivíduo mutado:  [99, 82, 41, 95]
#
#
# Indivíduo original:  [99, 82, 41, 95]
# Indivíduo mutado:  [99, 82, 41, 80]
#
#
# Indivíduo original:  [99, 82, 41, 95]
# Indivíduo mutado:  [99, 82, 99, 95]
#
#
# Indivíduo original:  [99, 82, 41, 95]
# Indivíduo mutado:  [99, 96, 41, 95]
#
#
# Indivíduo original:  [99, 82, 99, 95]
# Indivíduo mutado:  [93, 82, 99, 95]
#
#
# Indivíduo original:  [99, 96, 99, 95]
# Indivíduo mutado:  [99, 96, 19, 95]
#
#
# Indivíduo original:  [99, 96, 19, 95]
# Indivíduo mutado:  [60, 96, 19, 95]
#
#
# Indivíduo original:  [99, 96, 19, 95]
# Indivíduo mutado:  [99, 96, 6, 95]
#
#
# Indivíduo original:  [60, 96, 19, 95]
# Indivíduo mutado:  [60, 35, 19, 95]
#
#
# Indivíduo original:  [99, 82, 19, 95]
# Indivíduo mutado:  [99, 82, 19, 46]
#
#
# Indivíduo original:  [99, 82, 19, 95]
# Indivíduo mutado:  [68, 82, 19, 95]
#
#
# Indivíduo original:  [99, 82, 19, 95]
# Indivíduo mutado:  [99, 82, 19, 71]
#
#
# Indivíduo original:  [99, 82, 19, 71]
# Indivíduo mutado:  [99, 82, 95, 71]
#
#
# Indivíduo original:  [99, 82, 19, 71]
# Indivíduo mutado:  [99, 31, 19, 71]
#
#
# Indivíduo original:  [99, 82, 19, 71]
# Indivíduo mutado:  [99, 82, 41, 71]
#
#
# Indivíduo original:  [99, 82, 19, 95]
# Indivíduo mutado:  [99, 19, 19, 95]
#
#
# Indivíduo original:  [99, 82, 19, 71]
# Indivíduo mutado:  [99, 82, 99, 71]
#
#
# Indivíduo original:  [99, 82, 19, 95]
# Indivíduo mutado:  [99, 82, 19, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [28, 82, 19, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [99, 51, 19, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [99, 82, 24, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [99, 82, 33, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [21, 82, 19, 35]
#
#
# Indivíduo original:  [99, 82, 24, 35]
# Indivíduo mutado:  [99, 11, 24, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [60, 82, 19, 35]
#
#
# Indivíduo original:  [99, 82, 19, 35]
# Indivíduo mutado:  [99, 19, 19, 35]
#
#
# Indivíduo original:  [60, 82, 19, 35]
# Indivíduo mutado:  [33, 82, 19, 35]
#
#
# Indivíduo original:  [33, 82, 19, 35]
# Indivíduo mutado:  [67, 82, 19, 35]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 32, 19, 35]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [43, 82, 19, 35]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 23, 19, 35]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 82, 19, 40]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 82, 19, 45]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 82, 44, 35]
#
#
# Indivíduo original:  [67, 82, 19, 35]
# Indivíduo mutado:  [67, 82, 1, 35]
#
#
# Indivíduo original:  [67, 82, 44, 35]
# Indivíduo mutado:  [86, 82, 44, 35]
#
#
# Indivíduo original:  [67, 82, 44, 35]
# Indivíduo mutado:  [89, 82, 44, 35]
#
#
# Indivíduo original:  [67, 82, 44, 35]
# Indivíduo mutado:  [67, 47, 44, 35]
#
#
# Indivíduo original:  [67, 82, 1, 35]
# Indivíduo mutado:  [76, 82, 1, 35]
#
#
# Indivíduo original:  [89, 82, 44, 35]
# Indivíduo mutado:  [46, 82, 44, 35]
#
#
# Indivíduo original:  [89, 82, 44, 35]
# Indivíduo mutado:  [89, 82, 44, 67]
#
#
# Indivíduo original:  [89, 82, 44, 35]
# Indivíduo mutado:  [89, 82, 20, 35]
#
#
# Indivíduo original:  [89, 82, 44, 35]
# Indivíduo mutado:  [89, 8, 44, 35]
#
#
# Indivíduo original:  [89, 82, 44, 35]
# Indivíduo mutado:  [89, 50, 44, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 7, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [41, 82, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [18, 82, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 51, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [75, 82, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 60, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 60]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 17, 20, 35]
#
#
# Indivíduo original:  [89, 17, 20, 35]
# Indivíduo mutado:  [89, 17, 93, 35]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 21]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 67]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 0]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 22]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 82, 20, 7]
#
#
# Indivíduo original:  [89, 82, 20, 35]
# Indivíduo mutado:  [89, 76, 20, 35]
#
#
# Indivíduo original:  [89, 76, 20, 35]
# Indivíduo mutado:  [20, 76, 20, 35]
#
#
# Indivíduo original:  [89, 76, 20, 35]
# Indivíduo mutado:  [89, 76, 79, 35]
#
#
# Indivíduo original:  [89, 76, 20, 35]
# Indivíduo mutado:  [89, 76, 93, 35]
#
#
# Indivíduo original:  [89, 76, 79, 35]
# Indivíduo mutado:  [89, 76, 79, 7]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [25, 76, 93, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [89, 63, 93, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [72, 76, 93, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [89, 76, 0, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [80, 76, 93, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [89, 76, 4, 35]
#
#
# Indivíduo original:  [89, 76, 93, 35]
# Indivíduo mutado:  [89, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [34, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 76, 52, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 35, 93, 55]
#
#
# Indivíduo original:  [89, 35, 93, 55]
# Indivíduo mutado:  [89, 35, 3, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [79, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [92, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 76, 28, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [49, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 76, 93, 47]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 48, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [74, 76, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 76, 36, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 87, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89, 93, 93, 55]
#
#
# Indivíduo original:  [89, 76, 93, 55]
# Indivíduo mutado:  [89,
 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 60, 71, 32]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 60, 6, 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 67, 71, 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 60, 42, 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 60, 71, 50]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 60, 71, 31]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [56, 60, 71, 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [31, 60, 71, 72]
#
#
# Indivíduo original:  [100, 60, 71, 72]
# Indivíduo mutado:  [100, 37, 71, 72]
#
#
# Indivíduo original:  [100, 37, 71, 72]
# Indivíduo mutado:  [100, 37, 71, 88]
#
#
# Indivíduo original:  [100, 37, 71, 88]
# Indivíduo mutado:  [100, 99, 71, 88]
#
#
# Indivíduo original:  [100, 99, 71, 72]
# Indivíduo mutado:  [19, 99, 71, 72]
#
#
# Indivíduo original:  [100, 99, 71, 88]
# Indivíduo mutado:  [100, 99, 68, 88]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 99, 56, 88]
#
#
# Indivíduo original:  [100, 99, 68, 72]
# Indivíduo mutado:  [100, 99, 68, 71]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 99, 78, 88]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 23, 68, 88]
#
#
# Indivíduo original:  [100, 99, 78, 88]
# Indivíduo mutado:  [0, 99, 78, 88]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 99, 68, 80]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 99, 0, 88]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [100, 99, 32, 88]
#
#
# Indivíduo original:  [100, 99, 68, 88]
# Indivíduo mutado:  [74, 99, 68, 88]
#
#
# Indivíduo original:  [100, 99, 78, 88]
# Indivíduo mutado:  [56, 99, 78, 88]
#
#
# Indivíduo original:  [100, 99, 78, 88]
# Indivíduo mutado:  [100, 99, 78, 85]
#
#
# Indivíduo original:  [100, 99, 78, 85]
# Indivíduo mutado:  [100, 99, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 99, 44, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 63, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 99, 52, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [31, 99, 78, 17]
#
#
# Indivíduo original:  [31, 99, 78, 17]
# Indivíduo mutado:  [31, 70, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 67, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 99, 38, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [53, 99, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 51, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [92, 99, 78, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 99, 75, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [100, 99, 34, 17]
#
#
# Indivíduo original:  [100, 99, 78, 17]
# Indivíduo mutado:  [24, 99, 78, 17]
#
#
# População final:
# [[100, 99, 78, 17], [100, 99, 78, 17], [100, 99, 78, 17], [100, 99, 78, 17], [100, 99, 78, 17], [100, 99, 78, 17]]

# %% [markdown]
# ## Conclusão
#
# <p style='text-align: justify'> A partir deste algoritmo genético, foi possível resolver o problema das caixas não-binárias. Ambos os experimentos 3 (problema da caixa binária) e este, 4, (problema das caixas não-binárias) são muito similares. O algoritmo desenvolvido, em comparação ao anterior, teve apenas algumas pequenas alterações, que se resumem a algumas das funções utilizadas (criação de genes, indivíduo, população, determinação da função objetivo, da que calcula fitness para a população e a de mutação, que deve considerar um range maior de valores possíveis para a mudança), haja visto que apenas era preciso considerar mais valores possíveis para se gerar um gene válido. O algoritmo desenvolvido foi, eficaz na resolução do problema, ainda mais que foi aprimorado, levando em consideração a aplicação de seleção, crossing-over e mutação.
#
# O algoritmo, assim como o anterior, é <b>probabilístico</b> por permitir diferentes resultados a cada vez que o código é rodado.
#
# Como, neste problema, está sendo considerado que as caixas podem assumir valores de 0 até 100, a variabilidade, comparando com o experimento anterior, é bem maior, assim, torna-se de mais dificuldade atingir o melhor resultado possível e a mutação tem um impacto de maior relevância. Alterar os parâmetros, como chance de mutação, foi algo feito para analisar se houve melhora ou piora do resultado final (no caso, foi positivo o impacto da mudança de 0.05 para 0.04) e é algo a ser considerado válido a se testar.</p>

# %% [markdown]
# ## Playground
