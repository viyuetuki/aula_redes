# %% [markdown]
# Descobrindo a senha
# ===================

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Usar um algoritmo genético para descobrir uma senha.

# %% [markdown]
# ## Descrição do problema

# %% [markdown]
# Neste problema, a função objetivo deve saber a senha correta e quantificar de alguma maneira o quão perto ou longe os palpites estão da solução (veja que isso é algo que não temos no mundo real. Nenhum site irá te dizer se você está acertando ou errando seu palpite). O critério de parada deste problema é quando a senha for descoberta.

# %% [markdown]
# ## Importações

# %%
# Importando 'random' e algumas funções criadas, do arquivo 'funcoes.py', a serem usadas no algoritmo 
# e as renomeando de maneira "auto-explicativa"

from funcoes import populacao_inicial_senha
from funcoes import funcao_objetivo_pop_senha
from funcoes import selecao_torneio_min
from funcoes import cruzamento_ponto_simples as funcao_cruzamento
from funcoes import mutacao_senha
import random

# Obs: As que foram deixas sem a parte de renomeação é porque terão posição de funções locais neste código. Então,
# serão renomeadas quando elas forem adaptadas para as especificidades deste problema.

# %% [markdown]
# ## Códigos e discussão

# %%
### CONSTANTES

# relacionadas à busca
TAMANHO_POP = 50
CHANCE_CRUZAMENTO = 0.5
CHANCE_MUTACAO = 0.05
NUM_COMBATENTES_NO_TORNEIO = 3

# relacionadas ao problema a ser resulvido
SENHA = "ni8_wei@yu*#19CiNlPuEmM-ec42-60&22-10$04"
LETRAS_POSSIVEIS = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890_@#*&%!$-"
NUM_GENES = len(SENHA)

# %%
# funções locais

def cria_populacao_inicial(tamanho, tamanho_senha):
    return populacao_inicial_senha(tamanho, tamanho_senha, LETRAS_POSSIVEIS)

def funcao_objetivo_pop(populacao):
    return funcao_objetivo_pop_senha(populacao, SENHA)

def funcao_selecao(populacao, fitness):
    return selecao_torneio_min(populacao, fitness, NUM_COMBATENTES_NO_TORNEIO)

def funcao_mutacao(individuo):
    return mutacao_senha(individuo, LETRAS_POSSIVEIS)

# %%
populacao = cria_populacao_inicial(TAMANHO_POP, NUM_GENES)

melhor_fitness_ja_visto = float("inf")  # escrevendo infinito em python

print("Progresso da melhor senha já vista:")

# especificando para o algoritmo rodar até se encontrar um indivíduo com fitness = 0
while melhor_fitness_ja_visto != 0:   
    
    # Seleção
    fitness = funcao_objetivo_pop(populacao)
    populacao = funcao_selecao(populacao, fitness)
    
    # Cruzamento
    pais = populacao[0::2]
    maes = populacao[1::2]
    
    contador = 0
    
    for pai, mae in zip(pais, maes):
        if random.random() <= CHANCE_CRUZAMENTO:
            filho1, filho2 = funcao_cruzamento(pai, mae)
            populacao[contador] = filho1
            populacao[contador + 1] = filho2
        
        contador = contador + 2   
        
    # Mutação
    for n in range(len(populacao)):
        if random.random() <= CHANCE_MUTACAO:
            individuo = populacao[n]
            populacao[n] = funcao_mutacao(individuo)            
            
    # melhor individuo já visto até agora
    fitness = funcao_objetivo_pop(populacao)
    menor_fitness = min(fitness)
    if menor_fitness < melhor_fitness_ja_visto:        
        posicao = fitness.index(menor_fitness)
        melhor_individuo_ja_visto = populacao[posicao]
        melhor_fitness_ja_visto = menor_fitness
        print("".join(melhor_individuo_ja_visto), "- fitness:", melhor_fitness_ja_visto)

print()
print("Melhor palpite da senha encontrado:")
print("".join(melhor_individuo_ja_visto))
# Out:
# Progresso da melhor senha já vista:
# _sQhzKyC5c8TBNRD6cNhHrhSlh%O*0BldKeR2z1j - fitness: 927
# OB6wDKo#e_WK-%FcPZesdjYlgq-bJYQkcJ25W907 - fitness: 902
# OB6wDKo#e_WK-%FcPZesdjYlp93&FPN#5bMFZ&-@ - fitness: 833
# _sQhzKyC5c8TBNRD6cNhHrhSlh%O*0QkcJ25W907 - fitness: 779
# _sQhzKyC5c8TBNRD6cNhHrhSlh%O*0Qk5bMF$&-@ - fitness: 767
# _sQhzKyC5c8TBNAlcqQl5mGCMbubN&D*Ob25W907 - fitness: 739
# _sQhzKy#e_WK-%FRAGQl5mG4eU2O*0QkcJ25W907 - fitness: 700
# _sQhzKyC5c8K-%FRAGQl5mG4eU2O*0QkcJ25W907 - fitness: 687
# _sQhzKy#e_WK-%FRAGQl5mG4eU2O*0Q*Ob25W907 - fitness: 639
# _sQhzKyC5c8K-%FRAGQl5mG4eU2O*0Q*Ob25W907 - fitness: 626
# _sQhzKy#e_WK-%FRAkQl5mG4eU2O*0D*Ob25W907 - fitness: 590
# _sQhzKy*e_WK-%FRAkQlYmG4eU2O*0D*Ob25W907 - fitness: 587
# _sQhzKy*e_WK-%FRAkQlYmG4eU2O*0D*cJ25W907 - fitness: 583
# _sQhzKyCe_WK-%FRAkQlYmG4eU2O*0D*Ob25W907 - fitness: 568
# _sQhzKyCe_WK-%FRAkQl5mG4eU2O*0Q*2b25W907 - fitness: 548
# _sQhzKyCe_WK-%FRAkQlYmG4eU2O*01*cJ25W907 - fitness: 545
# _sQhzKyCe_WK-%FRAkQl5mG4eU2O*0D*2b25W907 - fitness: 535
# _sQhzKyCe_WK-%FRAkQl5mG4eU2O*01*2b25W907 - fitness: 516
# _sBhzKy#e_8K-%FRAkQlYmG4ei2O*0D*2b25W907 - fitness: 511
# _sBhzKy#e_8K-%FRAkQlYmG4ei2O*01*2b25W907 - fitness: 492
# _sBhzKy#e_8K-%FRAkQlYmG4ei2O*01*2b25W607 - fitness: 489
# _sBhzKy#e_88-%FRAkQlYmG4ei2O*01*2b25W907 - fitness: 473
# _sQhzKyCe_88-%FRAkQlYmG4ei2O*01*2b25W907 - fitness: 462
# _sQhzKyCe_88-%FRAkQlYmG4ei2O*01*2c25W607 - fitness: 460
# _sBhzKyCe_88-%FRAkQlYmG4ei2O*01*2b25W907 - fitness: 447
# _sBhzKyCe_88-%FRAkQlYmG4ei2O*01*2b25W607 - fitness: 444
# _sQhzKyCe_88-%FRAkQlYmG4ei2O*01*2O25W607 - fitness: 440
# _sBhzKyCe_88-%FRAkQlYmG4ei2O*01*2O25W607 - fitness: 425
# _sQhziyCe_88-%FRAkQlYmG4ei2O*01*2O25W607 - fitness: 418
# _sBhziyCe_88-%FRAkQlYmG4ei2O*01*2O25W607 - fitness: 403
# _sBhziZCe_88-%FRAkQlYmG4ei2O*01*2O25W607 - fitness: 402
# _sBhziZCe_88-%FRAkQlYmG4ei2O*01*2N25W607 - fitness: 401
# _rBhziZCe_88-%FRAkQlYmG4ei2O*01*2N25W607 - fitness: 400
# _rBhziZCe_88-%FRAkQlYmG4ei2O*01*2N25W$07 - fitness: 382
# _sBhziZCe_&8-%FRAkQlYmG4ei2O*01*2N25W$07 - fitness: 373
# _rBhziZCe_88-%FRAkQlYmG4ei2O*01*2N25M$07 - fitness: 372
# _rB_ziZCe_88-%FRAkQlYmG4ei2O*01*2N25M$07 - fitness: 363
# _rBhziZCe_&8-%FRAkQlYmG4ei2O*01*2N25M$07 - fitness: 362
# _rB_ziZCe_&8-%FRAkQlYmG4ei2O*01*2N25M$07 - fitness: 353
# _rB_ziZCe_&8-%FRAkQlYmG4ei2O*31*2N25M$07 - fitness: 350
# _rB_ziZCe_&8-AFRAkQlYmG4ei2O*01*2N25M$07 - fitness: 341
# _rB_ziZCe_&8-AFRAkQlYmG4ei2O*31*2N25M$07 - fitness: 338
# _rB_zQZCe_&8-AFRAkQlYmG4ei2O*31*2N255$07 - fitness: 330
# _rB_ziZCe_&8-AFRAkQlYmG4ei2H*31*2N255$07 - fitness: 307
# _rB_ziZCe_&8-%FRAkQlYmG4ei2H*31*26255$07 - fitness: 295
# _rB_ziZCe_&8-AFRAkQlYmG4ei2O*31*26255$07 - fitness: 290
# _rB_ziZCe_&8-AFRAkQlYmG4ei2H*31*26255$07 - fitness: 283
# _rB_ziZCeg&8-AFRAkQlYmG4ei2H*31*26255$07 - fitness: 275
# _rB_ziZCe_&8-AFRNkQlYmG4ei2H*31*26255$07 - fitness: 270
# _rB_ziZCeg&8-AFRNkQlYmG4ei2H*31*26255$07 - fitness: 262
# _rB_ziZCeg&%-AFRNkQlYmG4ei2H*31*26255$07 - fitness: 243
# _rB_uiZCeg&%-AFRNkQlYmG4ei2H*31*26255$07 - fitness: 242
# _rB_uiZCeg&%-AFRNkQlYmG4eh2H*31*26255$07 - fitness: 241
# _rB_uiZCeg&%-AFRNkQlYmG-ei2H*31*26255$07 - fitness: 235
# _rB_uiZCxg&%-AFRNkQlYmG4ei2H*31*26255$07 - fitness: 223
# _rB_uiZCxg&%-AFRNkQlYmG-ei2H*31*26255$07 - fitness: 216
# _rB_uiZCxn&%-AFRNkQlYmG-ei2H*31*26255$07 - fitness: 209
# _rB_uiZCxn&%-AFRNkQl7mG-ei2H*31*26255$07 - fitness: 203
# _rB_uiZCxn&%-AFRNkQlYmG-ei20*31*26255$07 - fitness: 189
# _rB_uiZCxn&%-AFRNkQlYmG-ei20*31*26155$07 - fitness: 188
# _rB_uiZCxn&%-AFRNkQuYmG-ei20*31*26255$07 - fitness: 180
# _rB_uiZCxn&%-AFRNkQuYmG-ei20*31*26155$07 - fitness: 179
# _rB_uiZCxn&%-AFtNkQuYmG-ei20*31*26155$07 - fitness: 167
# _rB_ugZCxn&%-@EpNkQuYmG-ei40*41*26154$07 - fitness: 155
# _rB_ugZCxn&%-@EpNkQu4mG-ei40*41*26154$07 - fitness: 152
# _bB_ugZCxn&%-@EpNkQu4mG-ei40*41*26154$07 - fitness: 150
# _bB_ugZCxn&%-@EpNkQu4mG-ei40*41#26154$07 - fitness: 149
# _bB_ugZCxn&%-@EpNkQu4mO-ei40*41#26154$07 - fitness: 145
# _bB_ugeCxn&%-@EpNkQu4mO-ei40*41#26154$07 - fitness: 134
# _bB_ugeCxn&%-@EpNkQu4mO-ec40*41#26154$07 - fitness: 128
# _bB_ugeCxn&%-@DpNkQu4mO-ec40*41#26154$07 - fitness: 127
# _b1_ugeCxn&%-@EpNkQu4mO-ec40*41#26154$07 - fitness: 125
# _b1_ugeCxn&%-@DpNkQu4mO-ec40*41#26154$07 - fitness: 124
# _b1_ugeCxn&%-@DpNkQu4mO-ec40*41#26154$06 - fitness: 123
# _f1_ugeCxn&%-@DpNkQu4mO-ec40*41#26154$06 - fitness: 119
# _f1_ugeCxn&%-7DpNkQu4mO-ec40*41#26154$06 - fitness: 114
# _f1_ugeBxn&%-7DpNkQu4mO-ec40*41#26154$06 - fitness: 113
# _f1_ugeBxn&%-7DpNkQu4mO-ec40*41$26154$06 - fitness: 112
# _f1_ugeBxy&%-7DpNkQu4mO-ec40*41$26154$06 - fitness: 109
# _f1_ugeBxy&%-7DpNkQuSmO-ec40*41$26154$06 - fitness: 106
# _f1_ugeBxv&%-7DpNkQuSmO-ec40*41$26154$06 - fitness: 103
# tf1_ugeBxy&%-7DpNkQuSmO-ec40*41$26154$06 - fitness: 97
# tf1_ugeBxy&%-7DhNkQuSmO-ec40*41$26154$06 - fitness: 91
# tf1_ugeBxy&$-7DhNkQuSmO-ec40*41$26154$06 - fitness: 90
# tf1_vgeBxy&$-7DhNkQuSmO-ec40*41$26154$06 - fitness: 89
# tf1_vgeBxy&$-7DhNkQuSmO-ec40*41$26*54$06 - fitness: 88
# tf1_vdeBxy&$-7DhNkQuSmO-ec40*41$26*54$06 - fitness: 87
# tf1_vgeBxy&$-7DhNkQuSmO-ec40*41$26*50$06 - fitness: 84
# tf1_vdeBxy&$-7DhNkQuSmO-ec40*41$26*50$06 - fitness: 83
# tf1_vgeBxy&$-7DhNkQuSmM-ec40*41$26*50$06 - fitness: 82
# tf1_vdgBxy&$-7DhNkQuSmO-ec40*41$26*50$06 - fitness: 81
# tf1_vdgBxs&$-7DhNkQuSmO-ec40*41$26*50$06 - fitness: 79
# tf1_vdgBxy&$-7DhNkQuBmO-ec40*41$26*50$06 - fitness: 70
# tf1_vdgBxs&$-7DhNkQuBmO-ec40*41$26*50$06 - fitness: 68
# tf6_vdgBxs&$-7DhNkQuBmO-ec40*41$26*50$06 - fitness: 63
# tf6_vdgBxs&$-7DhNkQuBmO-ec40*41$24*50$06 - fitness: 61
# tf6_vdgBxt&$-7DhNkQuBmO-ec40*41$24*50$06 - fitness: 60
# tf6_vdgBxt&$-7DhNlQuBmO-ec40*41$24*50$06 - fitness: 59
# tf6_vdgBxt&$-7DhNlQuBmO-ec40*41$22*50$06 - fitness: 57
# tf6_vdgBxt&$-7DhNlQuGmO-ec40*41$22*50$06 - fitness: 56
# tf6_vdgBxt&$-9DhNlQuBmO-ec40*41$22*50$06 - fitness: 55
# tf6_vdjBxt&$-9DhNlQuBmO-ec40*41$22*50$06 - fitness: 54
# ti6_vdjBxt&$-9DhNlQuBmO-ec40*41$22*50$06 - fitness: 51
# ti6_vdjAxt&$-9DhNlQuBmO-ec40*41$22*50$06 - fitness: 50
# ti6_vdjAxt&$39DhNlQuBmO-ec40*41$22*50$06 - fitness: 48
# ti6_vdjAxt&$39DhNlQuBmO-ec40*41&22*50$06 - fitness: 46
# ti6_vdjAxt&$39DhNlQuBmO-ec40*41&22*30$06 - fitness: 44
# ti6_vdjAxt&$39DhNlQuBmO-ec40*41&22*10$06 - fitness: 42
# ii6_vdjAxt&$39DhNlQuBmO-ec40*41&22*10$06 - fitness: 41
# ii6_vdj@xt&$39DhNlQuBmO-ec40*41&22*10$06 - fitness: 40
# ii6_vdj@xt&$29DhNlQuBmO-ec40*41&22*10$06 - fitness: 39
# ii6_vdj@xt&$29DhNlQuBmO-ec42*41&22*10$06 - fitness: 37
# ii6_vdi@xt&$29DhNlQuBmO-ec42*41&22*10$06 - fitness: 36
# ii6_vdi@xt&$29DhNlQuBmM-ec42*41&22*10$06 - fitness: 34
# ii6_vdi@xt&$29DhNlQuBmM-ec42*41&22-10$06 - fitness: 31
# pi6_vdi@xt&$29DhNlQuBmM-ec42*41&22-10$06 - fitness: 28
# pi6_vdi@xt*$29DhNlQuBmM-ec42*41&22-10$06 - fitness: 24
# pi8_vdi@xt*$29DhNlQuBmM-ec42*41&22-10$06 - fitness: 22
# pi8_vdi@xt*$29DhNlQuGmM-ec42*41&22-10$06 - fitness: 21
# pi8_vdi@xt*$29DhNlQuGmM-ec42*41&22-10$03 - fitness: 20
# pi8_vdi@xt*$29DhNlQuDmM-ec42*41&22-10$03 - fitness: 19
# pi8_vdi@xt*$19DhNlQuDmM-ec42*41&22-10$03 - fitness: 18
# pi8_wdi@xt*$19DhNlQuDmM-ec42*41&22-10$03 - fitness: 17
# pi8_wei@xt*$19DhNlQuDmM-ec42*41&22-10$03 - fitness: 16
# pi8_wei@xt*$19DhNlQuDmM-ec42*41&22-10$04 - fitness: 15
# mi8_wei@xt*$19DhNlQuDmM-ec42*41&22-10$04 - fitness: 14
# mi8_wei@xt*$19DhNlQuDmM-ec42*61&22-10$04 - fitness: 12
# mi8_wei@xt*$19DhNlQuEmM-ec42*61&22-10$04 - fitness: 11
# ni8_wei@xt*$19DhNlQuEmM-ec42*61&22-10$04 - fitness: 10
# ni8_wei@xt*$19DiNlQuEmM-ec42*61&22-10$04 - fitness: 9
# ni8_wei@yt*$19DiNlQuEmM-ec42*61&22-10$04 - fitness: 8
# ni8_wei@yu*$19DiNlQuEmM-ec42*61&22-10$04 - fitness: 7
# ni8_wei@yu*#19DiNlQuEmM-ec42*61&22-10$04 - fitness: 6
# ni8_wei@yu*#19DiNlQuEmM-ec42*60&22-10$04 - fitness: 5
# ni8_wei@yu*#19DiNlPuEmM-ec42*60&22-10$04 - fitness: 4
# ni8_wei@yu*#19DiNlPuEmM-ec42-60&22-10$04 - fitness: 1
# ni8_wei@yu*#19CiNlPuEmM-ec42-60&22-10$04 - fitness: 0
#
# Melhor palpite da senha encontrado:
# ni8_wei@yu*#19CiNlPuEmM-ec42-60&22-10$04

# %% [markdown]
# ## Conclusão
#
# Com este algoritmo, foi possível resolvermos o problema de descobrir a senha. Nele, utilizamos o operador de seleção por torneio, mantivemos o operador de cruzamento simples, e, diferentemente dos experimentos anteriores, os genes que compõem os indivíduos que, por sua vez, formam a população, são criados aleatoriamente a partir de uma lista de caracteres fornecida. Ademais, a função objetivo desta vez conta com a função ord(), que transforma cada caractere em um número ordinal respectivo, para ser possível calcular a distância de cada gene de um indivíduo em relação a senha original. Assim, quanto menor a distância, mais próximo está de acertar, logo, a função fitness é menor. Outro fato inserido é o hall da fama que, no caso, seria o melhor indivíduo já visto, que, pelo nome, já é autoexplicativa sua função de selecionar o melhor individuo de acordo com os critérios de minimização de fitness.
#
# Cabe ressaltar que, neste experimento, o problema é de minimização e não mais maximização, como era até anteriormente. Além disso, é interessante dizer que tal experimento se caracteriza como probabilístico, haja visto que, a cada vez que é rodado, resulta em tentativas diferentes.
#
# Variações que piorariam o algoritmo seriam: se, para os combatentes (na seleção por torneio mínimo), n (tamanho da população) fossem escolhidos, já que englobaria todos da população, sendo apenas o melhor indivíduo dela escolhido, e, por conseguinte, diminuindo a variabilidade genética; ou se 1 fosse escolhido, pois funcionaria como uma ferramenta de busca aleatória. Com isso, o ideal varia entre 3 e 5 escolhidos para o combate.
#
# Uma aplicabilidade para tal código, já que esse cenário da senha não é nada realístico, seria a comparação e tentativa de encontrar uma sequência de DNA, por exemplo, que se assemelha a outra já conhecida. Com isso, é possível ver o quão distante está da sequência, quais são os genes distantes, avaliar diferentes sequências e analisar quais mais se aproximam de uma dada.

# %% [markdown]
# ## Playground
